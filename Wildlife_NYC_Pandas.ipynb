# %% [markdown]
# # Brown Scholars Internship 2019-2020 - Urban Wildlife in NYC

# %% [markdown]
# New York City is home to many diverse species of wildlife that arrived or existed long before humans settled here.
# In October 2016, Mayor Bill de Blasio launched WildlifeNYC, a citywide education and awareness campaign teaching New Yorkers how to live safely and responsibly alongside wild animals including deer, raccoons, and coyotes.
#
# Urban wildlife is any wild animal that lives in an urban environment, such as New York City. Urban wildlife includes birds, mammals, reptiles, fish and amphibians. Some urban wildlife is native, like eastern grey squirrels, while some are non-native, like mute swans. Domesticated and companion animals, like dogs, exotic pets, and farm animals are not considered urban wildlife. Domesticated but feral animals like pigeons and stray cats are also not considered urban wildlife.
#
# Data source: https://data.cityofnewyork.us/Environment/Urban-Park-Ranger-Animal-Condition-Response/fuhs-xmg2

# %% [markdown]
# First we'll start by importing packages we'll use

# %%
import pandas as pd

# %% [markdown]
# and then import the data. For now, the csv file should be in the same directory as the notebook. Notice that we are importing the date and time info as type 'datetime'

# %%
data = pd.read_csv('Urban_Park_Ranger_Animal_Condition_Response.csv',
                   parse_dates = ['Date and Time of initial call', 'Date and time of Ranger response'])

# %% [markdown]
# Note: if you want to export the data, use df.to_csv(filename), where df is the name of your dataframe and filename is the name of the file where you want to save the data. The csv file will get created in the same directory as the notebook.

# %% [markdown]
# #### Step 1: Viewing and inspecting the data

# %% [markdown]
# Now that the data is loaded, let's check it out. To learn more about what the data looks like we can try the following commands:
# - data.head( ) - to look at the first 5 rows
# - data.tail( ) - to look at the last 5 rows
# - data.shape - to get the number of rows and columns
# - data.info( ) - to get the names of the columns, how many non null pieces of data is in each column, and the type of data in each column
# - data.nunique( ) - to get how many unique values are in each column
# - data.max() - to get the highest value in each column
# - data.min() to get the lowest value in each column
# - data['col'].value_counts() - to get how many unique values are in a particular column

# %%
data.head()
# Out:
#   Date and Time of initial call Date and time of Ranger response  \
# 0           2019-06-12 09:20:00              2019-06-12 09:20:00
# 1           2019-06-11 16:15:00              2019-06-11 16:20:00
# 2           2019-06-10 13:00:00              2019-06-10 13:30:00
# 3           2019-06-09 09:30:00              2019-06-09 10:00:00
# 4           2019-06-09 12:50:00              2019-06-09 12:55:00
#
#          Borough                Property  \
# 0      Manhattan  Washingtom Square Park
# 1          Bronx      Van Cortlandt Park
# 2       Brooklyn      Irving Square Park
# 3       Brooklyn           Parade Ground
# 4  Staten Island        Silver Lake Park
#
#                                             Location Species Description  \
# 0  on Sidewalk accross from the park near 10 Wash...     Red-tailed Hawk
# 1                          Adjacent to VC Golf House        Canada Goose
# 2                       Northwest corner of the park              Parrot
# 3    Prospect Park Parade Grounds near Tennis Center             Chicken
# 4                                             Bridge    Red-Eared Slider
#
#   Call Source Species Status Animal Condition  Duration of Response  ...  \
# 0       Other         Native              NaN                   0.5  ...
# 1      Public         Native          Injured                   0.5  ...
# 2      Public         Exotic              NaN                   1.5  ...
# 3     Central       Domestic          Healthy                   3.0  ...
# 4    Employee       Invasive          Injured                   2.0  ...
#
#      311SR Number      Final Ranger Action # of Animals PEP Response  \
# 0             NaN  Advised/Educated others          1.0        False
# 1  1-1-1733837211                Unfounded          1.0        False
# 2             NaN                Unfounded          1.0        False
# 3  1-1-1730643971                      ACC          1.0        False
# 4  1-1-1724490913                      ACC          2.0         True
#
#    Animal Monitored Rehabilitator Hours spent monitoring Police Response  \
# 0             False           NaN                    NaN           False
# 1             False           NaN                    NaN           False
# 2             False           NaN                    NaN           False
# 3             False           NaN                    NaN           False
# 4             False           NaN                    NaN           False
#
#    ESU Response ACC Intake Number
# 0         False               NaN
# 1         False               NaN
# 2         False               NaN
# 3         False             65352
# 4         False       65379 65380
#
# [5 rows x 22 columns]

# %%
data.tail()
# Out:
#     Date and Time of initial call Date and time of Ranger response    Borough  \
# 977           2018-06-05 00:00:00              2018-06-05 00:01:00  Manhattan
# 978           2018-06-01 12:00:00              2018-06-01 12:30:00  Manhattan
# 979           2018-05-16 09:00:00              2018-05-17 10:10:00  Manhattan
# 980           2018-05-02 09:30:00              2018-05-02 12:00:00  Manhattan
# 981           2018-05-07 13:30:00              2018-05-07 13:40:00  Manhattan
#
#              Property Location Species Description Call Source Species Status  \
# 977   Abingdon Square      NaN             raccoon     Central         Native
# 978      Central Park      NaN             RACCOON    Employee         Native
# 979  Morningside Park      NaN             Raccoon    Employee         Native
# 980      Central Park      NaN             raccoon      Public         Native
# 981      Central Park      NaN     Red Tailed Hawk    Employee         Native
#
#     Animal Condition  Duration of Response  ... 311SR Number  \
# 977          Healthy                  0.75  ...          NaN
# 978          Injured                  1.25  ...          NaN
# 979              DOA                  1.50  ...          NaN
# 980          Healthy                  0.75  ...          NaN
# 981              DOA                  1.00  ...          NaN
#
#                Final Ranger Action # of Animals PEP Response  \
# 977  Relocated/Condition Corrected          1.0        False
# 978                            ACC          1.0        False
# 979                            ACC          2.0        False
# 980                      Unfounded          1.0          NaN
# 981      Submitted for DEC Testing          1.0          NaN
#
#      Animal Monitored Rehabilitator Hours spent monitoring Police Response  \
# 977              True           NaN                    1.0           False
# 978             False           NaN                    NaN           False
# 979              True           NaN                    0.5           False
# 980               NaN           NaN                    NaN             NaN
# 981               NaN           NaN                    NaN             NaN
#
#      ESU Response ACC Intake Number
# 977         False               NaN
# 978         False             36061
# 979         False             28316
# 980         False               NaN
# 981         False               NaN
#
# [5 rows x 22 columns]

# %%
data.shape
# Out:
# (982, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 22 columns):
# Date and Time of initial call       982 non-null datetime64[ns]
# Date and time of Ranger response    982 non-null datetime64[ns]
# Borough                             982 non-null object
# Property                            982 non-null object
# Location                            918 non-null object
# Species Description                 969 non-null object
# Call Source                         982 non-null object
# Species Status                      968 non-null object
# Animal Condition                    758 non-null object
# Duration of Response                982 non-null float64
# Age                                 982 non-null object
# Animal Class                        982 non-null object
# 311SR Number                        573 non-null object
# Final Ranger Action                 982 non-null object
# # of Animals                        974 non-null float64
# PEP Response                        980 non-null object
# Animal Monitored                    980 non-null object
# Rehabilitator                       53 non-null object
# Hours spent monitoring              120 non-null float64
# Police Response                     980 non-null object
# ESU Response                        982 non-null bool
# ACC Intake Number                   402 non-null object
# dtypes: bool(1), datetime64[ns](2), float64(3), object(16)
# memory usage: 162.1+ KB

# %%
data.min()
# Out:
# Date and Time of initial call       2018-05-02 09:30:00
# Date and time of Ranger response    2018-05-02 12:00:00
# Borough                                           Bronx
# Property                                5 East 102nd St
# Call Source                                     Central
# Duration of Response                                  0
# Age                                               Adult
# Animal Class                                      Birds
# Final Ranger Action                                 ACC
# # of Animals                                          0
# PEP Response                                      False
# Animal Monitored                                  False
# Hours spent monitoring                             0.15
# Police Response                                   False
# ESU Response                                      False
# dtype: object

# %%
data['Borough'].value_counts()
# Out:
# Manhattan        475
# Brooklyn         218
# Queens           137
# Staten Island     84
# Bronx             68
# Name: Borough, dtype: int64

# %%
data.max()
# Out:
# Date and Time of initial call                    2019-06-12 09:20:00
# Date and time of Ranger response                 2019-06-12 09:20:00
# Borough                                                Staten Island
# Property                                            private property
# Call Source                                                   Public
# Duration of Response                                              21
# Age                                                  Juvenile;#Adult
# Animal Class                        Terrestrial Reptile or Amphibian
# Final Ranger Action                                        Unfounded
# # of Animals                                                      11
# PEP Response                                                    True
# Animal Monitored                                                True
# Hours spent monitoring                                             4
# Police Response                                                 True
# ESU Response                                                    True
# dtype: object

# %% [markdown]
# #### Step 2: Cleaning the data

# %% [markdown]
# By now, we should have a sense of which columns may have null values. It may be or not be ok for a column to have null values. One way to replace null values with some other value is using, use data.fillna(x) where x is the value we want instead of the null.

# %% [markdown]
# In addition, the data may not be in 'standard' form, that is for example, having the strings 'yes', 'YES', and 'Yes' all be values contained in the same column. To verify that the data in a column is in 'standard' form, we can use data['column_name'].unique(). For example, what happens when we try data['Species Description'].unique()? What happens when we try data['Species Status'].unique()? To replace values, we can use data['column name'].replace('yes','Yes') to replace all 'yes' values with 'Yes' values (for example).

# %%
data['Animal Class'].unique()
# Out:
# array(['Raptors', 'Birds', 'Domestic', 'Terrestrial Reptile or Amphibian',
#        'Small Mammals-RVS', 'Rare, Endangered, Dangerous',
#        'Small Mammals-non RVS', 'Marine Reptiles',
#        'Fish-numerous quantity;#Terrestrial Reptile or Amphibian',
#        'Domestic;#Birds', 'Marine Mammals-seals only',
#        'Marine Mammals-whales, Dolphin', 'Deer', 'Coyotes',
#        'Domestic;#Small Mammals-RVS', 'Fish-numerous quantity',
#        'Domestic;#Small Mammals-non RVS', 'Small Mammals-RVS;#Raptors'],
#       dtype=object)

# %%
data['Species Description'].unique()
# Out:
# array(['Red-tailed Hawk', 'Canada Goose', 'Parrot', 'Chicken',
#        'Red-Eared Slider', 'Rd-tailed Hawk', 'Cormorant', 'Raccoon',
#        'Rooster', 'Dove', 'Snapping turtle', 'Monk Parakeet',
#        'Mallard Duck', 'Gull', 'Snake', 'Snapping Turtle', 'Opossum',
#        'Red-eyed Vireo', 'turtle', 'Squirrel', 'American Robin',
#        'Domestic Duck', 'Pigeon', 'Bat', 'sparrow', nan,
#        'Domestic Rabbit', 'Fledgling (possibly Starling)', 'Guineafowl',
#        'American Goldfinch', 'Bird/Unspecified Species',
#        'Freshwater Fish and Turtles', 'Turtle/ Unspecified species',
#        'Cat', 'silver-haired bat', 'Seal', 'Egret', 'Skunk',
#        'Painted Turtle', 'Northern Gannet', 'Parakeet', 'Cockatiel',
#        'Saw whet owl', 'Dog', 'Robin', 'Big Brown Bat', 'Corn Snake',
#        'Mute Swan', 'Coopers Hawk', 'Harbor Porpoise',
#        'Boa Constrictor Snake', 'Turkey', 'Deer', 'Dolphin', 'Coyote',
#        'Swan', 'Harbor Seal', 'Frog', 'Woodcock', 'Brant Goose', 'Falcon',
#        "Cooper's Hawk", 'Herring Gull', 'Duck', 'White throated sparrow',
#        'Blue Jay', 'Guinea Pigs', 'Racoon', 'house sparrow',
#        'Sharp Shinned Hawk', 'raccoon', 'Northern Saw-whet Owl',
#        'Ring-Billed Gull', 'Duck (species unknown)', 'woodcock', 'Turtle',
#        'Ruddy Duck', 'bat', 'cormorant', 'Hawk', 'Silver-haired Bat',
#        'Chinese Silky Chicken', 'squirrel', 'Rabbit', 'Muskrat',
#        'Yellow Bellied Sapsucker', 'Red-Bellied Woodpecker', 'gull',
#        'Warbler', 'Groundhog', 'White Tailed Deer', 'Gray squirrel',
#        'Brant', 'Goose - White Pygmy', 'yellow bellied sap-sucker',
#        'Mandarin Duck', 'Nashville warbler', 'House Sparrow',
#        'Downy woodpecker', 'Domestic Dove', 'Common Snapping Turtle',
#        'Alligator snapping turtle', 'mallard duck', 'Unknown Species',
#        'Yellow Crowned Night Heron', 'unknown',
#        'Double crested cormorant', 'Canada goose', 'bird of prey',
#        'Rock Dove', 'Red-Tailed Hawk', 'Banded Rock Pigeon',
#        'Eastern Gray Squirrel', 'Painted turtle', 'Black Skimmer',
#        'Hummingbird', 'Green Heron', 'Black Racer Snake', 'Homing Pigeon',
#        '2 black back gulls and 1 pigeon', 'pet rabbit', 'red tailed-hawk',
#        'pigeon', 'Bearded dragon', 'Red-tailed hawk', 'Gerbil',
#        'Black backed gull', 'White-tailed deer', 'Mourning Dove',
#        'Red Tail', 'Iguana', 'Red-eared Slider Turtle',
#        'Peregrine Falcon', 'Kestrel', 'Red Bat', 'Red Tailed Hawk',
#        'Mallard duck', 'crow', 'Herring gull', 'Squirrells',
#        'Infant Squirrel', 'American Oystercatcher', 'opossum',
#        'dutch blue love bird', 'double crested cormorant', 'RACCOON'],
#       dtype=object)

# %%
data['Species Status'].unique()
# Out:
# array(['Native', 'Exotic', 'Domestic', 'Invasive', nan], dtype=object)

# %%
data['Location'].fillna(0)
# Out:
# 0      on Sidewalk accross from the park near 10 Wash...
# 1                              Adjacent to VC Golf House
# 2                           Northwest corner of the park
# 3        Prospect Park Parade Grounds near Tennis Center
# 4                                                 Bridge
# 5                          Southeast Section of the park
# 6       Under the nest near Avenue B and East 9th Street
# 7      Hawk Nest (Near Avenue B and East 9th Entrance...
# 8                                       Tide Gate Bridge
# 9                                       Tide Gate Bridge
# 10                          144th Street and 20th Avenue
# 11     outside of playground in the brush close to pe...
# 12            Inside Miricale Gardens (community Garden)
# 13                   Rockaway Beach 97th St. PEP Command
# 14          Dyker 14th Ballfields; 40.613081, -74.014714
# 15     Behind the Met Museum at East Drive and East 84th
# 16                                     Perimeter of park
# 17        40.792282, -73.959797 North Meadow Ballfield 4
# 18                    CPW drive at field by W 100st pool
# 19                                  Unspecified Location
# 20                             Orchard Beach Parking Lot
# 21     Hawk Nest Near Avenue B and East 10th entrance...
# 22                                  Playground and field
# 23                                       79st/Transverse
# 24     W110th and CPW; opposite from the playground a...
# 25                              Blue Heron Nature Center
# 26                   Near 5th Ave & 41st Street Entrance
# 27                                            Near water
# 28                                   40.80788, -73.85810
# 29                                 Lincoln Road entrance
#                              ...
# 952    Lasker pool laying in-between the fence posts ...
# 953                                                    0
# 954                                    Space time plygnd
# 955                       Strawberry Fields by the Drive
# 956                                                    0
# 957                 alleyway of the Lasker Rink and Pool
# 958                                                    0
# 959                                                    0
# 960                                                    0
# 961                                                    0
# 962                                                    0
# 963                                                    0
# 964                                                    0
# 965                                                    0
# 966                                                    0
# 967                                                    0
# 968                                                    0
# 969                                                    0
# 970                                                    0
# 971                                                    0
# 972                                                    0
# 973                                                    0
# 974                                                    0
# 975                                                    0
# 976                                                    0
# 977                                                    0
# 978                                                    0
# 979                                                    0
# 980                                                    0
# 981                                                    0
# Name: Location, Length: 982, dtype: object

# %% [markdown]
# #### Step 3: Exploring the data

# %% [markdown]
# Once our data is in the shape that we need it to be, we can start exploring it. To learn more about what the data can tell us we'll try filtering and grouping it, also computating some basic statistics and making graphs. The decisions that we make when doing all this can be based on our knowledge of the topic, our curiosity to learn from the data, as well as informed by what we learn from the data (or all three!).

# %% [markdown]
# ##### Filtering data

# %% [markdown]
# To filter data, the following commands are useful:
#
# - data[col] - to work only with one column
# - data[data[col] > 7] - to extract rows that meet a particular criteria
# - data[(data[col] > 0.5) & (data[col] < 0.7)] - to extract rows that meet more than one criteria

# %%
data[(data['Duration of Response'] > 1.0) & (data['Duration of Response'] < 3.0)]
# Out:
#     Date and Time of initial call Date and time of Ranger response  \
# 2             2019-06-10 13:00:00              2019-06-10 13:30:00
# 4             2019-06-09 12:50:00              2019-06-09 12:55:00
# 5             2019-06-08 11:00:00              2019-06-08 11:15:00
# 6             2019-06-08 08:44:00              2019-06-08 09:20:00
# 7             2019-06-06 10:00:00              2019-06-07 12:00:00
# 8             2019-06-07 15:15:00              2019-06-08 09:30:00
# 9             2019-06-07 15:15:00              2019-06-07 15:20:00
# 12            2019-06-06 10:00:00              2019-06-06 10:45:00
# 14            2019-06-05 11:00:00              2019-06-05 11:20:00
# 20            2019-06-01 15:00:00              2019-06-01 14:30:00
# 26            2019-05-26 11:00:00              2019-05-26 12:00:00
# 28            2019-05-23 14:00:00              2019-05-24 15:00:00
# 30            2019-05-22 09:30:00              2019-05-22 09:30:00
# 34            2019-05-22 14:50:00              2019-05-22 15:34:00
# 37            2019-05-20 11:00:00              2019-05-20 11:45:00
# 44            2019-05-15 11:15:00              2019-05-15 11:35:00
# 48            2019-05-11 13:10:00              2019-05-11 13:10:00
# 50            2019-05-12 11:00:00              2019-05-12 11:30:00
# 60            2019-05-09 09:00:00              2019-05-09 09:00:00
# 67            2019-05-03 11:25:00              2019-05-03 11:30:00
# 69            2019-05-02 12:30:00              2019-05-02 13:30:00
# 81            2019-04-23 14:45:00              2019-04-23 15:00:00
# 83            2019-04-23 10:00:00              2019-04-23 10:06:00
# 84            2019-04-22 10:30:00              2019-04-22 13:21:00
# 87            2019-04-21 14:00:00              2019-04-21 14:48:00
# 89            2019-04-17 11:30:00              2019-04-17 11:45:00
# 90            2019-04-19 13:00:00              2019-04-19 13:05:00
# 91            2019-04-19 09:45:00              2019-04-19 09:55:00
# 93            2019-04-18 09:45:00              2019-04-18 13:30:00
# 94            2019-04-18 08:00:00              2019-04-18 09:30:00
# ..                            ...                              ...
# 903           2018-07-21 09:15:00              2018-07-21 09:15:00
# 913           2018-07-19 09:00:00              2018-07-19 10:00:00
# 914           2018-07-19 12:00:00              2018-07-19 00:30:00
# 917           2018-07-18 12:40:00              2018-07-18 13:00:00
# 920           2018-07-18 11:45:00              2018-07-18 13:00:00
# 921           2018-07-18 09:30:00              2018-07-18 10:00:00
# 929           2018-07-16 11:00:00              2018-07-16 11:00:00
# 932           2018-07-16 14:40:00              2018-07-16 14:50:00
# 934           2018-07-12 11:00:00              2018-07-12 12:00:00
# 937           2018-07-14 11:00:00              2018-07-14 11:15:00
# 938           2018-07-12 16:37:00              2018-07-12 17:15:00
# 942           2018-07-13 14:30:00              2018-07-13 14:30:00
# 943           2018-07-13 09:00:00              2018-07-13 09:30:00
# 946           2018-07-12 10:30:00              2018-07-12 10:50:00
# 951           2018-07-08 10:00:00              2018-07-08 10:30:00
# 955           2018-07-07 09:15:00              2018-07-07 09:36:00
# 958           2018-07-05 13:58:00              2018-07-05 13:58:00
# 959           2018-07-05 11:30:00              2018-07-05 12:16:00
# 962           2018-06-28 15:50:00              2018-06-28 16:00:00
# 963           2018-06-12 08:30:00              2018-06-14 14:00:00
# 965           2018-06-22 14:45:00              2018-06-22 15:00:00
# 966           2018-06-24 10:00:00              2018-06-24 11:00:00
# 970           2018-06-16 14:00:00              2018-06-16 02:30:00
# 971           2018-06-15 14:00:00              2018-06-15 14:52:00
# 972           2018-06-15 14:00:00              2018-06-15 16:30:00
# 973           2018-06-17 14:30:00              2018-06-17 15:40:00
# 975           2018-06-12 14:00:00              2018-06-12 02:35:00
# 976           2018-06-11 10:15:00              2018-06-11 10:30:00
# 978           2018-06-01 12:00:00              2018-06-01 12:30:00
# 979           2018-05-16 09:00:00              2018-05-17 10:10:00
#
#            Borough                                     Property  \
# 2         Brooklyn                           Irving Square Park
# 4    Staten Island                             Silver Lake Park
# 5        Manhattan                       Washington Square Park
# 6        Manhattan                         Tompkins Square Park
# 7        Manhattan                         Tompkins Square Park
# 8           Queens                 Flushing Meadows Corona Park
# 9           Queens                 Flushing Meadows Corona Park
# 12           Bronx                              851 Fairmont Pl
# 14        Brooklyn                             Dyker Beach Park
# 20           Bronx                                Orchard Beach
# 26        Brooklyn                                  Sunset Park
# 28           Bronx                                 Harding Park
# 30        Brooklyn                             Dyker Beach Park
# 34          Queens                                 Kissena Park
# 37   Staten Island                             Willowbrook Park
# 44   Staten Island                         South Beach Wetlands
# 48          Queens                                  Forest Park
# 50          Queens                           Cambria Playground
# 60           Bronx        Williamsbridge Oval Recreation Center
# 67          Queens                              Alley Pond Park
# 69   Staten Island                             Willowbrook Park
# 81       Manhattan                                 Central Park
# 83   Staten Island                              Blue Heron Park
# 84          Queens                 Rockaway Beach and Boardwalk
# 87          Queens                                 Astoria Park
# 89          Queens                                 Kissena Park
# 90          Queens                                 Kissena Park
# 91        Brooklyn                            Calvert Vaux Park
# 93       Manhattan                             Morningside Park
# 94       Manhattan                             Inwood Hill Park
# ..             ...                                          ...
# 903      Manhattan                                 Central Park
# 913      Manhattan                                 Central Park
# 914      Manhattan                                 Central Park
# 917      Manhattan                            West Harlem Piers
# 920  Staten Island  Ocean Breeze Track & Field Athletic Complex
# 921          Bronx                                  Haffen Park
# 929      Manhattan                                 Central Park
# 932         Queens  Alley Pond Park Tennis Courts Near Court 16
# 934       Brooklyn                                Prospect Park
# 937      Manhattan                                 Central Park
# 938      Manhattan                                 Central Park
# 942          Bronx                           Van Cortlandt Park
# 943      Manhattan                                 Central Park
# 946      Manhattan                                 Central Park
# 951      Manhattan                                 Central Park
# 955      Manhattan                                 Central Park
# 958  Staten Island                            Ocean Breeze Park
# 959         Queens                                  Forest Park
# 962      Manhattan                                 Central Park
# 963      Manhattan                               Riverside Park
# 965      Manhattan                                 Central Park
# 966      Manhattan                                 Central Park
# 970      Manhattan                               Riverside Park
# 971      Manhattan                                 Central Park
# 972      Manhattan                                 Central Park
# 973      Manhattan                                 Central Park
# 975      Manhattan                                 Central Park
# 976      Manhattan                               Riverside Park
# 978      Manhattan                                 Central Park
# 979      Manhattan                             Morningside Park
#
#                                               Location  \
# 2                         Northwest corner of the park
# 4                                               Bridge
# 5                        Southeast Section of the park
# 6     Under the nest near Avenue B and East 9th Street
# 7    Hawk Nest (Near Avenue B and East 9th Entrance...
# 8                                     Tide Gate Bridge
# 9                                     Tide Gate Bridge
# 12          Inside Miricale Gardens (community Garden)
# 14        Dyker 14th Ballfields; 40.613081, -74.014714
# 20                           Orchard Beach Parking Lot
# 26                 Near 5th Ave & 41st Street Entrance
# 28                                 40.80788, -73.85810
# 30                            13th ave and 86th street
# 34   Oak Ave and Underhill Ave across from the play...
# 37                             Next to comfort station
# 44   South Beach Jetty between Beach command and So...
# 48                          Forest Park Visitor Center
# 50                    Francis Lewis Blvd and 120th Ave
# 60     Williamsbridge Oval Park (Unspecified Location)
# 67                       Springfield Blvd and 74th Ave
# 69                                           Near pond
# 81                    on Glade arch by the  Maple tree
# 83   Intersection of green and red trail close to S...
# 84                Beach 23rd Street inside plover site
# 87                                   Basketball Courts
# 89                          Underhill Ave and 164th St
# 90                          Underhill Ave and 164th St
# 91                               40.585782, -73.991013
# 93                           Northern Morningside Park
# 94   40.867995, -73.927794 cross streets: Beak St a...
# ..                                                 ...
# 903                Central Park East Drive at 106th St
# 913                                    CP 79th St Yard
# 914                 Walking path to Delocorte Thearter
# 917              125 street and West Harlem Piers Park
# 920                                                NaN
# 921                                                NaN
# 929                                  103st and 5th ave
# 932                                                NaN
# 934                                                NaN
# 937                               Conservatory Gardens
# 938                      base of stairs to the Arsenal
# 942                                                NaN
# 943                                  93st & Bridlepath
# 946                           Play ground east 67th St
# 951                                                NaN
# 955                     Strawberry Fields by the Drive
# 958                                                NaN
# 959                                                NaN
# 962                                                NaN
# 963                                                NaN
# 965                                                NaN
# 966                                                NaN
# 970                                                NaN
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 975                                                NaN
# 976                                                NaN
# 978                                                NaN
# 979                                                NaN
#
#                Species Description                        Call Source  \
# 2                           Parrot                             Public
# 4                 Red-Eared Slider                           Employee
# 5                   Rd-tailed Hawk                             Public
# 6                  Red-tailed Hawk                             Public
# 7                  Red-tailed Hawk                             Public
# 8                        Cormorant                           Employee
# 9                        Cormorant                           Employee
# 12                         Rooster                           Employee
# 14                         Raccoon                           Employee
# 20                            Gull                             Public
# 26                         Opossum                            Central
# 28                         Rooster                           Employee
# 30                         Raccoon                            Central
# 34                 Snapping Turtle                            Central
# 37                   Domestic Duck                           Employee
# 44                 Snapping turtle                           Employee
# 48   Fledgling (possibly Starling)                             Public
# 50                      Guineafowl                            Central
# 60        Bird/Unspecified Species                           Employee
# 67                             Cat                            Central
# 69                    Canada Goose                           Employee
# 81                        Squirrel                             Public
# 83                           Skunk                 Observed by Ranger
# 84                 Northern Gannet                           Employee
# 87                        Parakeet                             Public
# 89                         Raccoon                           Employee
# 90                         Raccoon                           Employee
# 91                         Raccoon                           Employee
# 93                         Raccoon                              Other
# 94                         Raccoon                             Public
# ..                             ...                                ...
# 903                        Raccoon                 Observed by Ranger
# 913                        Raccoon  Conservancies/"Friends of" Groups
# 914                        Raccoon                           Employee
# 917                   Canada Goose                            Central
# 920                   Canada Goose                           Employee
# 921                        Raccoon                            Central
# 929                        Raccoon                           Employee
# 932                        Raccoon                            Central
# 934                        Raccoon                           Employee
# 937                        Raccoon  Conservancies/"Friends of" Groups
# 938                         pigeon                           Employee
# 942                Infant Squirrel                              Other
# 943                        Raccoon  Conservancies/"Friends of" Groups
# 946                        Raccoon  Conservancies/"Friends of" Groups
# 951                        Raccoon  Conservancies/"Friends of" Groups
# 955                            NaN  Conservancies/"Friends of" Groups
# 958                      Cormorant                           Employee
# 959                        Raccoon                           Employee
# 962                        Raccoon                              Other
# 963                Red-tailed Hawk                             Public
# 965                            NaN                           Employee
# 966                        Raccoon                            Central
# 970                Red-tailed Hawk                             Public
# 971       double crested cormorant                             Public
# 972                        raccoon  Conservancies/"Friends of" Groups
# 973                        Raccoon  Conservancies/"Friends of" Groups
# 975                        Raccoon  Conservancies/"Friends of" Groups
# 976                Red-tailed Hawk                             Public
# 978                        RACCOON                           Employee
# 979                        Raccoon                           Employee
#
#     Species Status Animal Condition  Duration of Response  ...  \
# 2           Exotic              NaN                  1.50  ...
# 4         Invasive          Injured                  2.00  ...
# 5           Native          Healthy                  1.50  ...
# 6           Native              NaN                  1.50  ...
# 7           Native        Unhealthy                  2.00  ...
# 8           Native          Injured                  1.50  ...
# 9           Native          Injured                  2.50  ...
# 12        Domestic          Healthy                  2.00  ...
# 14          Native        Unhealthy                  2.00  ...
# 20          Native          Injured                  2.00  ...
# 26          Native          Injured                  2.00  ...
# 28        Domestic        Unhealthy                  2.50  ...
# 30          Native        Unhealthy                  1.50  ...
# 34          Native          Injured                  1.50  ...
# 37        Domestic          Healthy                  2.00  ...
# 44          Native              DOA                  1.50  ...
# 48          Native          Healthy                  2.50  ...
# 50          Native          Injured                  2.00  ...
# 60             NaN        Unhealthy                  2.00  ...
# 67        Domestic          Injured                  2.50  ...
# 69          Native          Injured                  1.25  ...
# 81          Native          Injured                  1.75  ...
# 83          Native        Unhealthy                  1.25  ...
# 84          Native          Injured                  2.25  ...
# 87        Domestic              NaN                  1.25  ...
# 89          Native              NaN                  1.50  ...
# 90          Native          Injured                  1.50  ...
# 91          Native        Unhealthy                  1.50  ...
# 93          Native              DOA                  1.50  ...
# 94          Native              DOA                  1.50  ...
# ..             ...              ...                   ...  ...
# 903         Native        Unhealthy                  2.00  ...
# 913         Native        Unhealthy                  2.75  ...
# 914         Native          Injured                  1.50  ...
# 917         Native        Unhealthy                  1.50  ...
# 920         Native          Injured                  1.25  ...
# 921         Native          Healthy                  1.25  ...
# 929         Native        Unhealthy                  2.00  ...
# 932         Native              NaN                  2.00  ...
# 934         Native          Healthy                  1.50  ...
# 937         Native        Unhealthy                  2.00  ...
# 938         Native        Unhealthy                  1.50  ...
# 942         Native              NaN                  2.00  ...
# 943         Native        Unhealthy                  2.00  ...
# 946         Native        Unhealthy                  1.50  ...
# 951         Native              DOA                  2.00  ...
# 955         Native        Unhealthy                  2.00  ...
# 958         Native        Unhealthy                  1.50  ...
# 959         Native              DOA                  2.00  ...
# 962         Native          Injured                  1.50  ...
# 963         Native          Healthy                  2.00  ...
# 965         Native          Healthy                  1.25  ...
# 966         Native          Injured                  2.00  ...
# 970         Native          Healthy                  2.50  ...
# 971         Native              NaN                  1.75  ...
# 972         Native          Healthy                  1.50  ...
# 973         Native        Unhealthy                  1.50  ...
# 975         Native          Injured                  2.00  ...
# 976         Native          Injured                  2.00  ...
# 978         Native          Injured                  1.25  ...
# 979         Native              DOA                  1.50  ...
#
#          311SR Number            Final Ranger Action # of Animals  \
# 2                 NaN                      Unfounded          1.0
# 4      1-1-1724490913                            ACC          2.0
# 5                 NaN               Monitored Animal          1.0
# 6      1-1-1727159802                  Rehabilitator          1.0
# 7                 NaN               Monitored Animal          1.0
# 8                 NaN                      Unfounded          1.0
# 9                 NaN               Monitored Animal          1.0
# 12     1-1-1729971530                            ACC          3.0
# 14     1-1-1728538570                            ACC          1.0
# 20      1-1-173378903                  Rehabilitator          1.0
# 26     1-1-1726194712                            ACC          1.0
# 28   1-1-1 7178168040                            ACC          2.0
# 30                NaN                      Unfounded          1.0
# 34     1-1-1724432609                  Rehabilitator          1.0
# 37                NaN                            ACC          5.0
# 44                NaN  Relocated/Condition Corrected          1.0
# 48      1-1-171611660                  Rehabilitator          1.0
# 50     1-1-1715195702                            ACC          1.0
# 60    1-1-17 14404721                  Rehabilitator          5.0
# 67     1-1-1716062206                            ACC          1.0
# 69                NaN               Monitored Animal          2.0
# 81     1-1-1709390570  Relocated/Condition Corrected          1.0
# 83     1-1-1710353230                            ACC          1.0
# 84     1-1-1709572321                            ACC          1.0
# 87                NaN                      Unfounded          1.0
# 89                NaN                      Unfounded          1.0
# 90                NaN                      Unfounded          1.0
# 91     1-1-1705092230                            ACC          1.0
# 93     1-1-1706046820                            ACC          1.0
# 94     1-1-1709864080                            ACC          1.0
# ..                ...                            ...          ...
# 903    1-1-1591297971                            ACC          1.0
# 913    1-1-1590496247                            ACC          1.0
# 914    1-11-590496249                            ACC          1.0
# 917    1-1-1590963990                  Rehabilitator          1.0
# 920    1-1-1590963990                            ACC          1.0
# 921    1-1-1589094020  Relocated/Condition Corrected          1.0
# 929    1-11-587740050                            ACC          1.0
# 932               NaN                      Unfounded          0.0
# 934               NaN                      Unfounded          1.0
# 937    1-1-1588847790                            ACC          1.0
# 938               NaN  Relocated/Condition Corrected          1.0
# 942    1-11-588704060                  Rehabilitator          1.0
# 943    1-11-585670172                            ACC          1.0
# 946    1-11-585601187                            ACC          1.0
# 951               NaN                            ACC          NaN
# 955    1-11-584114940                            ACC          1.0
# 958    1-11-584298431                            ACC          1.0
# 959               NaN  Relocated/Condition Corrected          3.0
# 962    1-11-578998211                            ACC          1.0
# 963               NaN               Monitored Animal          1.0
# 965               NaN  Relocated/Condition Corrected          1.0
# 966    1-11-580068259                            ACC          1.0
# 970    1-11-572509140                  Rehabilitator          1.0
# 971               NaN                      Unfounded          1.0
# 972               NaN  Relocated/Condition Corrected          1.0
# 973    1-11-576043760                            ACC          1.0
# 975    1-11-579641512                            ACC          1.0
# 976   1-11-5729099901                  Rehabilitator          1.0
# 978               NaN                            ACC          1.0
# 979               NaN                            ACC          2.0
#
#     PEP Response  Animal Monitored              Rehabilitator  \
# 2          False             False                        NaN
# 4           True             False                        NaN
# 5          False              True                        NaN
# 6          False             False      Animal Medical Center
# 7          False              True                        NaN
# 8          False             False                        NaN
# 9          False              True                        NaN
# 12         False             False                        NaN
# 14         False             False                        NaN
# 20         False             False              Wildbird Fund
# 26         False             False                        NaN
# 28         False             False                        NaN
# 30         False             False                        NaN
# 34         False             False              Bobby Horvath
# 37         False             False                        NaN
# 44         False             False                        NaN
# 48         False             False              Wild Bird Fun
# 50         False             False                        NaN
# 60          True             False             Wild Bird Fund
# 67         False             False                        NaN
# 69         False              True                        NaN
# 81         False             False                        NaN
# 83         False             False                        NaN
# 84         False             False                        NaN
# 87         False             False                        NaN
# 89         False             False                        NaN
# 90         False             False                        NaN
# 91         False              True                        NaN
# 93         False             False                        NaN
# 94         False             False                        NaN
# ..           ...               ...                        ...
# 903        False             False                        NaN
# 913        False             False                        NaN
# 914        False             False                        NaN
# 917        False             False  Wild Bird Fund, Manhattan
# 920         True             False                        NaN
# 921        False             False                        NaN
# 929        False             False                        NaN
# 932        False             False                        NaN
# 934        False             False                        NaN
# 937        False             False                        NaN
# 938        False             False                        NaN
# 942        False             False                        NaN
# 943        False             False                        NaN
# 946        False             False                        NaN
# 951        False             False                        NaN
# 955        False             False                        NaN
# 958        False             False                        NaN
# 959        False             False                        NaN
# 962        False              True                        NaN
# 963        False              True                        NaN
# 965        False             False                        NaN
# 966        False             False                        NaN
# 970        False              True              Bobby Horvath
# 971        False             False                        NaN
# 972        False             False                        NaN
# 973        False             False                        NaN
# 975        False             False                        NaN
# 976        False              True              Bobby Horvath
# 978        False             False                        NaN
# 979        False              True                        NaN
#
#     Hours spent monitoring Police Response  ESU Response ACC Intake Number
# 2                      NaN           False         False               NaN
# 4                      NaN           False         False       65379 65380
# 5                     1.50           False         False               NaN
# 6                      NaN           False         False               NaN
# 7                     1.00           False         False               NaN
# 8                      NaN           False         False               NaN
# 9                     0.25           False         False               NaN
# 12                     NaN           False         False             83788
# 14                     NaN            True         False             64980
# 20                     NaN           False         False               NaN
# 26                     NaN           False         False             64014
# 28                     NaN           False         False      63836, 63837
# 30                     NaN           False         False               NaN
# 34                     NaN           False         False               NaN
# 37                     NaN           False         False    1-1-1721095361
# 44                     NaN           False         False               NaN
# 48                     NaN           False         False               NaN
# 50                     NaN           False         False             62613
# 60                     NaN           False         False               NaN
# 67                     NaN           False         False             61753
# 69                    1.25           False         False               NaN
# 81                     NaN           False         False               NaN
# 83                     NaN           False         False             60772
# 84                     NaN           False         False             60715
# 87                     NaN           False         False               NaN
# 89                     NaN           False         False               NaN
# 90                     NaN           False         False               NaN
# 91                    0.15           False         False             60407
# 93                     NaN           False         False             60355
# 94                     NaN           False         False             60330
# ..                     ...             ...           ...               ...
# 903                    NaN           False         False             35291
# 913                    NaN           False         False             35069
# 914                    NaN           False         False             35104
# 917                    NaN           False         False               NaN
# 920                    NaN           False         False             34955
# 921                    NaN           False         False               NaN
# 929                    NaN           False         False             34680
# 932                    NaN           False         False               NaN
# 934                    NaN           False         False               NaN
# 937                    NaN           False         False             34433
# 938                    NaN           False         False               NaN
# 942                    NaN           False         False               NaN
# 943                    NaN           False         False             34281
# 946                    NaN           False         False             34206
# 951                    NaN           False         False               NaN
# 955                    NaN           False         False             40666
# 958                    NaN           False         False             40434
# 959                    NaN           False         False               NaN
# 962                    NaN           False         False             39582
# 963                   2.00           False         False               NaN
# 965                    NaN           False         False               NaN
# 966                    NaN           False         False             32202
# 970                   1.00           False         False               NaN
# 971                    NaN           False         False               NaN
# 972                    NaN           False         False               NaN
# 973                    NaN           False         False             31565
# 975                    NaN           False         False             37529
# 976                   2.00           False         False               NaN
# 978                    NaN           False         False             36061
# 979                   0.50           False         False             28316
#
# [402 rows x 22 columns]

# %%
data['# of Animals']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      2.0
# 5      1.0
# 6      1.0
# 7      1.0
# 8      1.0
# 9      1.0
# 10     0.0
# 11     1.0
# 12     3.0
# 13     1.0
# 14     1.0
# 15     1.0
# 16     1.0
# 17     1.0
# 18     1.0
# 19     2.0
# 20     1.0
# 21     1.0
# 22     1.0
# 23     1.0
# 24     1.0
# 25     1.0
# 26     1.0
# 27     1.0
# 28     2.0
# 29     2.0
#       ...
# 952    1.0
# 953    1.0
# 954    3.0
# 955    1.0
# 956    1.0
# 957    1.0
# 958    1.0
# 959    3.0
# 960    1.0
# 961    NaN
# 962    1.0
# 963    1.0
# 964    1.0
# 965    1.0
# 966    1.0
# 967    1.0
# 968    1.0
# 969    2.0
# 970    1.0
# 971    1.0
# 972    1.0
# 973    1.0
# 974    1.0
# 975    1.0
# 976    1.0
# 977    1.0
# 978    1.0
# 979    2.0
# 980    1.0
# 981    1.0
# Name: # of Animals, Length: 982, dtype: float64

# %%
data[data['# of Animals'] > 7]
# Out:
#     Date and Time of initial call Date and time of Ranger response  \
# 421           2018-11-03 17:00:00              2018-11-05 13:55:00
# 477           2018-10-19 15:20:00              2018-10-19 16:00:00
#
#            Borough           Property                               Location  \
# 421  Staten Island   Willowbrook Park                                   Pond
# 477       Brooklyn  Garden Playground  Beaver St. Between Fayette and Egbert
#
#     Species Description Call Source Species Status Animal Condition  \
# 421       Domestic Duck    Employee       Domestic              NaN
# 477        Canada Goose    Employee         Native              DOA
#
#      Duration of Response  ... 311SR Number Final Ranger Action # of Animals  \
# 421                  1.25  ...          NaN    Monitored Animal         11.0
# 477                  1.00  ...          NaN           Unfounded          9.0
#
#     PEP Response  Animal Monitored Rehabilitator Hours spent monitoring  \
# 421        False              True           NaN                    0.5
# 477        False             False           NaN                    NaN
#
#     Police Response  ESU Response ACC Intake Number
# 421           False         False               NaN
# 477           False         False               NaN
#
# [2 rows x 22 columns]

# %%
data["Species Description"].replace('racoon', "Raccon", inplace = True)

# %% [markdown]
# ##### Grouping data

# %% [markdown]
# To group data, the following commands are useful:
# - data[[col1, col2]] - to work with only some columns
# - data.groupby(col) - To group the data based on the values in one column
# - data.groupby([col1,col2]) - To group the data based on the values in more than one column
# - If we want to find out how big each group is, we can use use .size() to count the number of rows in each group.

# %%
g = data.groupby(['Animal Class','Age'])

# %%
g.size()
# Out:
# Animal Class                                              Age
# Birds                                                     Adult                      129
#                                                           Infant                      11
#                                                           Juvenile                    26
# Coyotes                                                   Adult                        6
# Deer                                                      Adult                       15
#                                                           Infant                       1
#                                                           Juvenile                     4
# Domestic                                                  Adult                       44
#                                                           Infant                       1
#                                                           Infant;#Juvenile             1
#                                                           Juvenile                    11
# Domestic;#Birds                                           Adult                        1
#                                                           Infant                       1
#                                                           Juvenile                     3
# Domestic;#Small Mammals-RVS                               Adult                        1
# Domestic;#Small Mammals-non RVS                           Adult                        1
# Fish-numerous quantity                                    Adult                        1
# Fish-numerous quantity;#Terrestrial Reptile or Amphibian  Adult;#Juvenile              1
# Marine Mammals-seals only                                 Adult                        3
#                                                           Juvenile                     3
# Marine Mammals-whales, Dolphin                            Adult                        2
# Marine Reptiles                                           Adult                        5
#                                                           Infant                       2
#                                                           Juvenile                     1
# Raptors                                                   Adult                       18
#                                                           Infant                       1
#                                                           Juvenile                    34
#                                                           Juvenile;#Adult              1
# Rare, Endangered, Dangerous                               Adult                        1
# Small Mammals-RVS                                         Adult                      421
#                                                           Adult;#Juvenile              2
#                                                           Adult;#Juvenile;#Infant      1
#                                                           Infant                      19
#                                                           Juvenile                   137
#                                                           Juvenile;#Adult              2
# Small Mammals-RVS;#Raptors                                Juvenile                     1
# Small Mammals-non RVS                                     Adult                       33
#                                                           Adult;#Juvenile;#Infant      1
#                                                           Infant                       5
#                                                           Juvenile                    10
# Terrestrial Reptile or Amphibian                          Adult                       20
#                                                           Adult;#Juvenile;#Infant      1
# dtype: int64

# %% [markdown]
# ##### Basic statistics

# %% [markdown]
# To compute some basic statistics we can use:
# - data.describe() - summary statistics for numerical columns
# - data.mean() - mean of all columns
# - data.median() - median of each column
# - data.std() - standard deviation of each column
# - data.corr() - to get the correlation between columns

# %%
data.describe()
# Out:
#        Duration of Response  # of Animals  Hours spent monitoring
# count            982.000000    974.000000              120.000000
# mean               1.389868      1.090349                0.966667
# std                1.135502      0.732486                0.847818
# min                0.000000      0.000000                0.150000
# 25%                0.750000      1.000000                0.500000
# 50%                1.000000      1.000000                0.500000
# 75%                2.000000      1.000000                1.000000
# max               21.000000     11.000000                4.000000

# %%
data.median()
# Out:
# Duration of Response      1.0
# # of Animals              1.0
# Hours spent monitoring    0.5
# ESU Response              0.0
# dtype: float64

# %%
data.mean()
# Out:
# Duration of Response      1.389868
# # of Animals              1.090349
# Hours spent monitoring    0.966667
# ESU Response              0.006110
# dtype: float64

# %%
data.std()
# Out:
# Duration of Response      1.135502
# # of Animals              0.732486
# Hours spent monitoring    0.847818
# ESU Response              0.077967
# dtype: float64

# %%
data.corr()
# Out:
#                         Duration of Response  # of Animals  \
# Duration of Response                1.000000      0.027589
# # of Animals                        0.027589      1.000000
# Hours spent monitoring              0.632575     -0.025882
# ESU Response                        0.046757     -0.009716
#
#                         Hours spent monitoring  ESU Response
# Duration of Response                  0.632575      0.046757
# # of Animals                         -0.025882     -0.009716
# Hours spent monitoring                1.000000      0.220775
# ESU Response                          0.220775      1.000000

# %% [markdown]
# ##### Making graphs

# %% [markdown]
# To visualize categorical data we can use:
# - g = data['col'].value_counts()
# - g.plot(x=g.index, y=g.values, kind = 'bar')or g.plot.pie(y='Borough')
